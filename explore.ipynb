# %%
import pandas as pd

# Load only the column names
df = pd.read_csv("new_data/new_balance_cashflow_incom_annualmerged.csv", nrows=0)

# Print all column names
print("Feature Names:")
print(df.columns.tolist())
# Out:
# Feature Names:
# ...

# %%
df.dtypes
# Out:
# stock                      object
# endDate                    object
# accountsPayable           float64
# inventory                 float64
# longTermDebt              float64
#                            ...
# incomeBeforeTax           float64
# researchDevelopment       float64
# otherOperatingExpenses    float64
# minorityInterest_y        float64
# discontinuedOperations    float64
# Length: 69, dtype: object

# %%
import pandas as pd


# Load only the column names
df = pd.read_csv("new_data/new_balance_cashflow_incom_quarterlymerged.csv", nrows=0)

# Print all column names
print("Feature Names:")
print(df.columns.tolist())
# Out:
# Feature Names:
# ...

# %%
# Out:
# Feature Names:
# ...
